# %% [markdown]
# <a href="https://colab.research.google.com/github/nadirju/AI-ML-Python_Learning/blob/main/ArithmeticFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basics of Python
print ("Python") #This is commented
# Out:
# Python

# %%
"Hello"
# Out:
# 'Hello'

# %%
'Hello'
# Out:
# 'Hello'

# %%
print("He siad'Yes I can do this'")
# Out:
# He siad'Yes I can do this'

# %%
print('He said "Yes I can do this"')
# Out:
# He said "Yes I can do this"

# %%
print (r"E:\STM32 Cube IDE\STM32CubeIDE_1.18.1")
# Out:
# E:\STM32 Cube IDE\STM32CubeIDE_1.18.1

# %%
print("E:/STM32 Cube IDE/STM32CubeIDE_1.18.1")
# Out:
# E:/STM32 Cube IDE/STM32CubeIDE_1.18.1

# %%
'Python'
# Out:
# 'Python'

# %%
8
# Out:
# 8

# %%
print("Addition:" ,5+3)
# Out:
# Addition: 8

# %%
print("Subtraction:", 5-2)
print("Multiplication:" ,5*2)
print("Division:" ,5/2)
print("Floor Division:" ,5//2)
print("Modulus:" ,5%2)
print("Exponentiation:" ,3**3)
# Out:
# Subtraction: 3
# Multiplication: 10
# Division: 2.5
# Floor Division: 2
# Modulus: 1
# Exponentiation: 27

# %%
5+4-2
# Out:
# 7

# %%
5+4-
# Out:
#   File "/tmp/ipython-input-1911768064.py", line 1
#     5+4-
#         ^
# SyntaxError: invalid syntax
