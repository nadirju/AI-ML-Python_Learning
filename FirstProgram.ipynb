# %% [markdown]
# <a href="https://colab.research.google.com/github/nadirju/AI-ML-Python_Learning/blob/main/FirstProgram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Mahdi")
# Out:
# Mahdi

# %%
print("Yes I can learn Python")
# Out:
# Yes I can learn Python

# %%
print(10)
# Out:
# 10

# %%
print(10)
print (100)
# Out:
# 10
# 100

# %%
7
# Out:
# 7

# %%
3+3
# Out:
# 6

# %%
5-3
# Out:
# 2

# %%
1000-999
# Out:
# 1

# %%
324324234892349732497342-23498972398432
# Out:
# 324324234868850760098910

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3305111549.py in <cell line: 0>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
"hello"
# Out:
# 'hello'

# %%
"Assalamoalaikum"
# Out:
# 'Assalamoalaikum'
