# %% [markdown]
# <a href="https://colab.research.google.com/github/nadirju/AI-ML-Python_Learning/blob/main/List%2C_Tuple%2C_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#List
L = ['Faisal', 'Amjad', 'Usman', 'Arif']

# %%
L[1]
# Out:
# 'Amjad'

# %%
L
# Out:
# ['Faisal', 'Amjad', 'Usman', 'Arif']

# %%
L[0]
# Out:
# 'Faisal'

# %%
L[3]
# Out:
# 'Arif'

# %%
#numbers List
N = [1,2,3,4,5]

# %%
#number and string mix list
A = [1, 2.34, 'Ali', 34]

# %%
N
# Out:
# [1, 2, 3, 4, 5]

# %%
A
# Out:
# [1, 2.34, 'Ali', 34]

# %%
mix = ['Ali', 32, 3.543]

# %%
mix
# Out:
# ['Ali', 32, 3.543]

# %%
ListOfList= [L,N,A]

# %%
ListOfList
# Out:
# [['Faisal', 'Amjad', 'Usman', 'Arif'], [1, 2, 3, 4, 5], [1, 2.34, 'Ali', 34]]

# %%
N
# Out:
# [1, 2, 3, 4, 5]

# %%
|N[2,3,4]
# Out:
#   File "/tmp/ipython-input-359251427.py", line 1
#     |N[2,3,4]
#     ^
# SyntaxError: invalid syntax

# %%
N[2,3,4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1456856046.py in <cell line: 0>()
# ----> 1 N[2,3,4]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
N[2:]
# Out:
# [3, 4, 5]

# %%
N.append(77)

# %%
N
# Out:
# [1, 2, 3, 4, 5, 'hadeed', '77']

# %%
N.clear('hadeed')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-16006298.py in <cell line: 0>()
# ----> 1 N.clear('hadeed')
#
# TypeError: list.clear() takes no arguments (1 given)

# %%
N.remove('hadeed')

# %%
N
# Out:
# [1, 2, 3, 4, 5, '77', 77]

# %%
N.remove('77')

# %%
N
# Out:
# [1, 2, 3, 4, 5, 77]

# %%
N.insert(4,80)

# %%
N
# Out:
# [1, 2, 3, 4, 80, 5, 77]

# %%
N.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1918014742.py in <cell line: 0>()
# ----> 1 N.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
N.count(1)
# Out:
# 1

# %%
N.append(80)

# %%
N
# Out:
# [1, 2, 3, 4, 80, 5, 77, 80]

# %%
N.count(80)
