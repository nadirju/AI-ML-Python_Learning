# %% [markdown]
# <a href="https://colab.research.google.com/github/nadirju/AI-ML-Python_Learning/blob/main/Variables%2C_Strings%2C_Indexes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
id=1234
name='Rogers'
phone=123-456-6789
email='abc@gmail.com'
print(234)
# Out:
# 234

# %%
print(id)
# Out:
# 1234

# %%
print(name)
# Out:
# Rogers

# %%
print(phone)
# Out:
# -7122

# %%
print(email)
# Out:
# abc@gmail.com

# %%
x=10
y=5
add = x+y
print(add)
# Out:
# 15

# %%
_x=45

# %%
print(_x)
# Out:
# 45

# %%
8x=45
# Out:
#   File "/tmp/ipython-input-580750149.py", line 1
#     8x=45
#     ^
# SyntaxError: invalid decimal literal

# %%
x=56

# %%
print(x)
# Out:
# 56

# %%
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2644917711.py in <cell line: 0>()
# ----> 1 print(Name)
#
# NameError: name 'Name' is not defined

# %%
print(name)
# Out:
# Rogers

# %%
print(NAME)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1048088141.py in <cell line: 0>()
# ----> 1 print(NAME)
#
# NameError: name 'NAME' is not defined

# %%
name='John'

# %%
input('Please enter your name')
# Out:
# Please enter your nameJOHN
# 'JOHN'

# %%
name = input()
# Out:
# James

# %%
print(name)
# Out:
# James

# %%
print(name)
name
# Out:
# James
# 'James'

# %%
name = 'Nadir' + 'Abbas'

# %%
name
# Out:
# 'NadirAbbas'

# %%
name = 'Nadir ' + 'Abbas' #concatinatiom

# %%
name
# Out:
# 'Nadir Abbas'

# %%
name= 'Python' + 7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1736797244.py in <cell line: 0>()
# ----> 1 name= 'Python' + 7
#
# TypeError: can only concatenate str (not "int") to str

# %%
name = 'python'

# %%
#python
#012345  p index 0, y index 1 and so on...
#string is an array of characters with each character assigned an index
name [0]
# Out:
# 'p'

# %%
name[3]
# Out:
# 'h'

# %%
name[5]
# Out:
# 'n'

# %%
name[-1]
# Out:
# 'n'

# %%
name[-4]
# Out:
# 't'

# %%
name[-40]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3095858435.py in <cell line: 0>()
# ----> 1 name[-40]
#
# IndexError: string index out of range

# %%
name[-3]
# Out:
# 'h'
